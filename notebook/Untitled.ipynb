# %%
import os
import pandas as pd
import sys
import warnings

# %%
pd.set_option("display.max_columns", 100)
pd.set_option("display.max_rows", 100)
warnings.filterwarnings("ignore")

sys.path.append(os.pardir)
sys.path.append('../..')

from src.dataloader import DataLoader
from src.utils import mkdir, load_joblib, load_yaml, save_joblib

config = load_yaml("../config.yml")
for k, v in config["path"].items():
    config["path"][k] = "." + v
config["path"]
# Out:
# {'aisles': '../input/instacart-market-basket-analysis/aisles.csv',
#  'departments': '../input/instacart-market-basket-analysis/departments.csv',
#  'order_products__prior': '../input/instacart-market-basket-analysis/order_products__prior.csv',
#  'order_products__train': '../input/instacart-market-basket-analysis/order_products__train.csv',
#  'orders': '../input/instacart-market-basket-analysis/orders.csv',
#  'products': '../input/instacart-market-basket-analysis/products.csv',
#  'sample_submission': '../input/instacart-market-basket-analysis/sample_submission.csv',
#  'column_series': '../input/column_series',
#  'feature': '../feature',
#  'importance': '../importance',
#  'logs': '../logs',
#  'model': '../model',
#  'preprocess': '../input/preprocess',
#  'submit': '../submit'}

# %% [markdown]
# ## Load

# %%
def load(config):
    dataloader = DataLoader(config)
    aisles = dataloader.load_csv(config["path"]["aisles"])
    departments = dataloader.load_csv(config["path"]["departments"])
    order_products_prior = dataloader.load_csv(config["path"]["order_products__prior"])
    order_products_train = dataloader.load_csv(config["path"]["order_products__train"])
    orders = dataloader.load_csv(config["path"]["orders"])
    products = dataloader.load_csv(config["path"]["products"])
    sample_submission = dataloader.load_csv(config["path"]["sample_submission"])
    return aisles, departments, order_products_prior, order_products_train, orders, products, sample_submission

aisles, departments, order_products_prior, order_products_train, orders, products, sample_submission = load(config)

# %%
for df, name in zip(
    [aisles, departments, order_products_prior, order_products_train, orders, products, sample_submission],
    ["aisles", "departments", "order_products_prior", "order_products_train", "orders", "products", "sample_submission"]
):
    print("\n", name, "\n", df.shape)
    display(df.head(3))
# Out:
#  aisles
#  (134, 2)
#    aisle_id                  aisle
# 0         1  prepared soups salads
# 1         2      specialty cheeses
# 2         3    energy granola bars
#  departments
#  (21, 2)
#    department_id department
# 0              1     frozen
# 1              2      other
# 2              3     bakery
#  order_products_prior
#  (32434489, 4)
#    order_id  product_id  add_to_cart_order  reordered
# 0         2       33120                  1          1
# 1         2       28985                  2          1
# 2         2        9327                  3          0
#  order_products_train
#  (1384617, 4)
#    order_id  product_id  add_to_cart_order  reordered
# 0         1       49302                  1          1
# 1         1       11109                  2          1
# 2         1       10246                  3          0
#  orders
#  (3421083, 7)
#    order_id  user_id eval_set  order_number  order_dow  order_hour_of_day  \
# 0   2539329        1    prior             1          2                  8
# 1   2398795        1    prior             2          3                  7
# 2    473747        1    prior             3          3                 12
#
#    days_since_prior_order
# 0                     NaN
# 1                    15.0
# 2                    21.0
#  products
#  (49688, 4)
#    product_id                          product_name  aisle_id  department_id
# 0           1            Chocolate Sandwich Cookies        61             19
# 1           2                      All-Seasons Salt       104             13
# 2           3  Robust Golden Unsweetened Oolong Tea        94              7
#  sample_submission
#  (75000, 2)
#    order_id     products
# 0        17  39276 29259
# 1        34  39276 29259
# 2       137  39276 29259

# %%
if not os.path.exists("./preprocess/prior.jbl"):
    prior = order_products_prior.merge(orders[orders["eval_set"]=="prior"], how="left", on="order_id")
    prior = prior.merge(products, how="left", on="product_id")
    prior.drop("eval_set", axis=1, inplace=True)
    prior.set_index("order_id", inplace=True)

    train = order_products_train.merge(orders[orders["eval_set"]=="train"], how="left", on="order_id")
    train = train.merge(products, how="left", on="product_id")
    train.drop("eval_set", axis=1, inplace=True)
    train.set_index("order_id", inplace=True)

    test = sample_submission.merge(orders[orders["eval_set"]=="test"], how="left", on="order_id")
    test.drop(["eval_set", "products"], axis=1, inplace=True)
    test.set_index("order_id", inplace=True)

    mkdir("./preprocess")
    save_joblib(prior, "./preprocess/prior.jbl")
    save_joblib(train, "./preprocess/train.jbl")
    save_joblib(test, "./preprocess/test.jbl")

else:
    prior = load_joblib("./preprocess/prior.jbl")
    train = load_joblib("./preprocess/train.jbl")
    test = load_joblib("./preprocess/test.jbl")

# %%
prior.head(3)
# Out:
#           product_id  add_to_cart_order  reordered  user_id  order_number  \
# order_id
# 2              33120                  1          1   202279             3
# 2              28985                  2          1   202279             3
# 2               9327                  3          0   202279             3
#
#           order_dow  order_hour_of_day  days_since_prior_order  \
# order_id
# 2                 5                  9                     8.0
# 2                 5                  9                     8.0
# 2                 5                  9                     8.0
#
#                    product_name  aisle_id  department_id
# order_id
# 2            Organic Egg Whites        86             16
# 2         Michigan Organic Kale        83              4
# 2                 Garlic Powder       104             13

# %%
train.head(3)
# Out:
#           product_id  add_to_cart_order  reordered  user_id  order_number  \
# order_id
# 1              49302                  1          1   112108             4
# 1              11109                  2          1   112108             4
# 1              10246                  3          0   112108             4
#
#           order_dow  order_hour_of_day  days_since_prior_order  \
# order_id
# 1                 4                 10                     9.0
# 1                 4                 10                     9.0
# 1                 4                 10                     9.0
#
#                                            product_name  aisle_id  \
# order_id
# 1                                      Bulgarian Yogurt       120
# 1         Organic 4% Milk Fat Whole Milk Cottage Cheese       108
# 1                                 Organic Celery Hearts        83
#
#           department_id
# order_id
# 1                    16
# 1                    16
# 1                     4

# %%
test.head(3)
# Out:
#           user_id  order_number  order_dow  order_hour_of_day  \
# order_id
# 17          36855             5          6                 15
# 34          35220            20          3                 11
# 137        187107             9          2                 19
#
#           days_since_prior_order
# order_id
# 17                           1.0
# 34                           8.0
# 137                         30.0

# %%
test.shape, test.user_id.unique().shape
# Out:
# ((75000, 5), (75000,))

# %%
prior.user_id.nunique(), train.user_id.nunique() + test.user_id.nunique(), train.user_id.nunique(), test.user_id.nunique()
# Out:
# (206209, 206209, 131209, 75000)

# %% [markdown]
# ## Subset

# %%
prior[prior["user_id"]==202279].sort_values(["order_number", "add_to_cart_order"])
# Out:
#           product_id  add_to_cart_order  reordered  user_id  order_number  \
# order_id
# 2894949         5812                  1          0   202279             1
# 2894949        24742                  2          0   202279             1
# 2894949        17794                  3          0   202279             1
# 2894949        28985                  4          0   202279             1
# 2894949        33120                  5          0   202279             1
# 2894949         1003                  6          0   202279             1
# 2894949        26504                  7          0   202279             1
# 2894949        34040                  8          0   202279             1
# 2894949         7206                  9          0   202279             1
# 2894949         5593                 10          0   202279             1
# 1500071        28985                  1          1   202279             2
# 1500071         1003                  2          1   202279             2
# 1500071          432                  3          0   202279             2
# 1500071        17794                  4          1   202279             2
# 1500071        14218                  5          0   202279             2
# 1500071        45918                  6          0   202279             2
# 1500071        40141                  7          0   202279             2
# 1500071        31275                  8          0   202279             2
# 1500071        24933                  9          0   202279             2
# 1500071        30878                 10          0   202279             2
# 1500071         1819                 11          0   202279             2
# 1500071         7993                 12          0   202279             2
# 2              33120                  1          1   202279             3
# 2              28985                  2          1   202279             3
# 2               9327                  3          0   202279             3
# 2              45918                  4          1   202279             3
# 2              30035                  5          0   202279             3
# 2              17794                  6          1   202279             3
# 2              40141                  7          1   202279             3
# 2               1819                  8          1   202279             3
# 2              43668                  9          0   202279             3
# 3058248        17794                  1          1   202279             4
# 3058248        31275                  2          1   202279             4
# 3058248        40141                  3          1   202279             4
# 3058248        27531                  4          0   202279             4
# 3058248         2944                  5          0   202279             4
# 3058248        38226                  6          0   202279             4
# 3058248        35106                  7          0   202279             4
# 3058248        12545                  8          0   202279             4
# 2808715        33120                  1          1   202279             5
# 2808715        28985                  2          1   202279             5
# 2808715         1003                  3          1   202279             5
# 2808715        17794                  4          1   202279             5
# 2808715        30035                  5          1   202279             5
# 2808715        40141                  6          1   202279             5
# 2808715        45918                  7          1   202279             5
# 2808715        43668                  8          1   202279             5
# 2808715        10644                  9          0   202279             5
# 2808715         6515                 10          0   202279             5
# 2808715         4461                 11          0   202279             5
# 132412         33120                  1          1   202279             6
# 132412          1003                  2          1   202279             6
# 132412         43668                  3          1   202279             6
# 132412         45918                  4          1   202279             6
# 132412         17794                  5          1   202279             6
# 132412         40141                  6          1   202279             6
# 132412         28985                  7          1   202279             6
# 132412         35106                  8          1   202279             6
# 132412         12545                  9          1   202279             6
# 132412         10960                 10          0   202279             6
# 132412         48023                 11          0   202279             6
# 2382766         1003                  1          1   202279             7
# 2382766        17794                  2          1   202279             7
# 2382766        45918                  3          1   202279             7
# 2382766        30035                  4          1   202279             7
# 2382766        31275                  5          1   202279             7
# 2382766        10960                  6          1   202279             7
# 2382766        12545                  7          1   202279             7
# 2382766        35106                  8          1   202279             7
# 2382766        44663                  9          0   202279             7
# 2382766        46372                 10          0   202279             7
# 2382766        16525                 11          0   202279             7
# 2382766        44910                 12          0   202279             7
# 2382766         2086                 13          0   202279             7
# 2382766        48023                 14          1   202279             7
# 2382766        47969                 15          0   202279             7
# 2382766        29130                 16          0   202279             7
# 2382766         8235                 17          0   202279             7
# 104690          1003                  1          1   202279             8
# 104690         33120                  2          1   202279             8
# 104690         10960                  3          1   202279             8
# 104690         29130                  4          1   202279             8
# 104690         24742                  5          1   202279             8
# 104690          2154                  6          0   202279             8
# 104690         21543                  7          0   202279             8
# 104690         42824                  8          0   202279             8
# 104690         20995                  9          0   202279             8
# 104690         45002                 10          0   202279             8
# 104690         24810                 11          0   202279             8
# 104690         42241                 12          0   202279             8
#
#           order_dow  order_hour_of_day  days_since_prior_order  \
# order_id
# 2894949           5                  9                     NaN
# 2894949           5                  9                     NaN
# 2894949           5                  9                     NaN
# 2894949           5                  9                     NaN
# 2894949           5                  9                     NaN
# 2894949           5                  9                     NaN
# 2894949           5                  9                     NaN
# 2894949           5                  9                     NaN
# 2894949           5                  9                     NaN
# 2894949           5                  9                     NaN
# 1500071           4                 13                    20.0
# 1500071           4                 13                    20.0
# 1500071           4                 13                    20.0
# 1500071           4                 13                    20.0
# 1500071           4                 13                    20.0
# 1500071           4                 13                    20.0
# 1500071           4                 13                    20.0
# 1500071           4                 13                    20.0
# 1500071           4                 13                    20.0
# 1500071           4                 13                    20.0
# 1500071           4                 13                    20.0
# 1500071           4                 13                    20.0
# 2                 5                  9                     8.0
# 2                 5                  9                     8.0
# 2                 5                  9                     8.0
# 2                 5                  9                     8.0
# 2                 5                  9                     8.0
# 2                 5                  9                     8.0
# 2                 5                  9                     8.0
# 2                 5                  9                     8.0
# 2                 5                  9                     8.0
# 3058248           3                 14                    30.0
# 3058248           3                 14                    30.0
# 3058248           3                 14                    30.0
# 3058248           3                 14                    30.0
# 3058248           3                 14                    30.0
# 3058248           3                 14                    30.0
# 3058248           3                 14                    30.0
# 3058248           3                 14                    30.0
# 2808715           5                 13                     9.0
# 2808715           5                 13                     9.0
# 2808715           5                 13                     9.0
# 2808715           5                 13                     9.0
# 2808715           5                 13                     9.0
# 2808715           5                 13                     9.0
# 2808715           5                 13                     9.0
# 2808715           5                 13                     9.0
# 2808715           5                 13                     9.0
# 2808715           5                 13                     9.0
# 2808715           5                 13                     9.0
# 132412            5                  9                    30.0
# 132412            5                  9                    30.0
# 132412            5                  9                    30.0
# 132412            5                  9                    30.0
# 132412            5                  9                    30.0
# 132412            5                  9                    30.0
# 132412            5                  9                    30.0
# 132412            5                  9                    30.0
# 132412            5                  9                    30.0
# 132412            5                  9                    30.0
# 132412            5                  9                    30.0
# 2382766           1                 14                    24.0
# 2382766           1                 14                    24.0
# 2382766           1                 14                    24.0
# 2382766           1                 14                    24.0
# 2382766           1                 14                    24.0
# 2382766           1                 14                    24.0
# 2382766           1                 14                    24.0
# 2382766           1                 14                    24.0
# 2382766           1                 14                    24.0
# 2382766           1                 14                    24.0
# 2382766           1                 14                    24.0
# 2382766           1                 14                    24.0
# 2382766           1                 14                    24.0
# 2382766           1                 14                    24.0
# 2382766           1                 14                    24.0
# 2382766           1                 14                    24.0
# 2382766           1                 14                    24.0
# 104690            6                 10                    30.0
# 104690            6                 10                    30.0
# 104690            6                 10                    30.0
# 104690            6                 10                    30.0
# 104690            6                 10                    30.0
# 104690            6                 10                    30.0
# 104690            6                 10                    30.0
# 104690            6                 10                    30.0
# 104690            6                 10                    30.0
# 104690            6                 10                    30.0
# 104690            6                 10                    30.0
# 104690            6                 10                    30.0
#
#                                              product_name  aisle_id  \
# order_id
# 2894949                 Natural Calm Magnesium Supplement        47
# 2894949    My Community Immune Support Dietary Supplement        47
# 2894949                                           Carrots        83
# 2894949                             Michigan Organic Kale        83
# 2894949                                Organic Egg Whites        86
# 2894949                         Organic Turkey Bone Broth         5
# 2894949                        Creamy & Raw Almond Butter        88
# 2894949      Organic Gut Shot Ginger Beet Probiotic Drink        81
# 2894949                  Cilantro Avocado Yogurt Dressing        89
# 2894949         Renew Life Total Body 7-Day Rapid Cleanse         6
# 1500071                             Michigan Organic Kale        83
# 1500071                         Organic Turkey Bone Broth         5
# 1500071                 Vanilla Almond Breeze Almond Milk        91
# 1500071                                           Carrots        83
# 1500071              Grade A Large Eggs Cage Free Omega 3        86
# 1500071                                    Coconut Butter        19
# 1500071                  Original Unflavored Gelatine Mix       105
# 1500071                  Organic High Fiber Coconut Flour        17
# 1500071                                     Turmeric Root        83
# 1500071                            Organic Chopped Ginger        72
# 1500071          All Natural No Stir Creamy Almond Butter        88
# 1500071    Dressing & Sandwich Spread Made with Olive Oil        88
# 2                                      Organic Egg Whites        86
# 2                                   Michigan Organic Kale        83
# 2                                           Garlic Powder       104
# 2                                          Coconut Butter        19
# 2                                       Natural Sweetener        17
# 2                                                 Carrots        83
# 2                        Original Unflavored Gelatine Mix       105
# 2                All Natural No Stir Creamy Almond Butter        88
# 2                                 Classic Blend Cole Slaw       123
# 3058248                                           Carrots        83
# 3058248                  Organic High Fiber Coconut Flour        17
# 3058248                  Original Unflavored Gelatine Mix       105
# 3058248       Dairy Free Unsweetened Vanilla Coconut Milk        53
# 3058248                   100% Organic Raw Coconut Butter        88
# 3058248                              Dark Chocolate Chips        45
# 3058248                         Broccoli Slaw Traditional       123
# 3058248               French Vanilla Coconut Milk Creamer        91
# 2808715                                Organic Egg Whites        86
# 2808715                             Michigan Organic Kale        83
# 2808715                         Organic Turkey Bone Broth         5
# 2808715                                           Carrots        83
# 2808715                                 Natural Sweetener        17
# 2808715                  Original Unflavored Gelatine Mix       105
# 2808715                                    Coconut Butter        19
# 2808715                           Classic Blend Cole Slaw       123
# 2808715                    Italian Extra Virgin Olive Oil        19
# 2808715              All Natural Cocoa Powder Unsweetened        17
# 2808715        Organic Raw Unfiltered Apple Cider Vinegar        19
# 132412                                 Organic Egg Whites        86
# 132412                          Organic Turkey Bone Broth         5
# 132412                            Classic Blend Cole Slaw       123
# 132412                                     Coconut Butter        19
# 132412                                            Carrots        83
# 132412                   Original Unflavored Gelatine Mix       105
# 132412                              Michigan Organic Kale        83
# 132412                          Broccoli Slaw Traditional       123
# 132412                French Vanilla Coconut Milk Creamer        91
# 132412                        Nutritional Yeast Seasoning       104
# 132412                           Wild Alaskan Pink Salmon        95
# 2382766                         Organic Turkey Bone Broth         5
# 2382766                                           Carrots        83
# 2382766                                    Coconut Butter        19
# 2382766                                 Natural Sweetener        17
# 2382766                  Organic High Fiber Coconut Flour        17
# 2382766                       Nutritional Yeast Seasoning       104
# 2382766               French Vanilla Coconut Milk Creamer        91
# 2382766                         Broccoli Slaw Traditional       123
# 2382766                    Naturals Lite Goddess Dressing        89
# 2382766                             Squeezed Orange Juice        31
# 2382766                            Organic Chopped Garlic        81
# 2382766                          Organic Spring Mix Salad       123
# 2382766                      Sustainably Soft Bath Tissue        54
# 2382766                          Wild Alaskan Pink Salmon        95
# 2382766          Argan Oil Cleansing Towelettes Unscented       109
# 2382766                Raw Manuka Honey Hi Active 15 Plus        29
# 2382766                                       Dry Shampoo        22
# 104690                          Organic Turkey Bone Broth         5
# 104690                                 Organic Egg Whites        86
# 104690                        Nutritional Yeast Seasoning       104
# 104690                 Raw Manuka Honey Hi Active 15 Plus        29
# 104690     My Community Immune Support Dietary Supplement        47
# 104690                Homestyle Savory Chicken Bone Broth        69
# 104690                                 Organic Quick Oats       130
# 104690                                    Black Eyed Peas       116
# 104690                           Organic Broccoli Florets       116
# 104690                 Organic Balsamic Vinegar Of Modena        19
# 104690            Organic Lightly Salted Brown Rice Cakes        78
# 104690    Organic Lightly Sweetened Sunflower Seed Butter        88
#
#           department_id
# order_id
# 2894949              11
# 2894949              11
# 2894949               4
# 2894949               4
# 2894949              16
# 2894949              13
# 2894949              13
# 2894949              15
# 2894949              13
# 2894949               2
# 1500071               4
# 1500071              13
# 1500071              16
# 1500071               4
# 1500071              16
# 1500071              13
# 1500071              13
# 1500071              13
# 1500071               4
# 1500071              13
# 1500071              13
# 1500071              13
# 2                    16
# 2                     4
# 2                    13
# 2                    13
# 2                    13
# 2                     4
# 2                    13
# 2                    13
# 2                     4
# 3058248               4
# 3058248              13
# 3058248              13
# 3058248              16
# 3058248              13
# 3058248              19
# 3058248               4
# 3058248              16
# 2808715              16
# 2808715               4
# 2808715              13
# 2808715               4
# 2808715              13
# 2808715              13
# 2808715              13
# 2808715               4
# 2808715              13
# 2808715              13
# 2808715              13
# 132412               16
# 132412               13
# 132412                4
# 132412               13
# 132412                4
# 132412               13
# 132412                4
# 132412                4
# 132412               16
# 132412               13
# 132412               15
# 2382766              13
# 2382766               4
# 2382766              13
# 2382766              13
# 2382766              13
# 2382766              13
# 2382766              16
# 2382766               4
# 2382766              13
# 2382766               7
# 2382766              15
# 2382766               4
# 2382766              17
# 2382766              15
# 2382766              11
# 2382766              13
# 2382766              11
# 104690               13
# 104690               16
# 104690               13
# 104690               13
# 104690               11
# 104690               15
# 104690               14
# 104690                1
# 104690                1
# 104690               13
# 104690               19
# 104690               13

# %%
train[train["user_id"]==202279].sort_values(["order_number", "add_to_cart_order"])
# Out:
#           product_id  add_to_cart_order  reordered  user_id  order_number  \
# order_id
# 1050357        33120                  1          1   202279             9
# 1050357         1003                  2          1   202279             9
# 1050357        21543                  3          1   202279             9
# 1050357        20995                  4          1   202279             9
# 1050357        46064                  5          0   202279             9
# 1050357        20168                  6          0   202279             9
# 1050357        42824                  7          1   202279             9
# 1050357         4461                  8          1   202279             9
# 1050357        45002                  9          1   202279             9
# 1050357         8693                 10          0   202279             9
#
#           order_dow  order_hour_of_day  days_since_prior_order  \
# order_id
# 1050357           1                 14                    30.0
# 1050357           1                 14                    30.0
# 1050357           1                 14                    30.0
# 1050357           1                 14                    30.0
# 1050357           1                 14                    30.0
# 1050357           1                 14                    30.0
# 1050357           1                 14                    30.0
# 1050357           1                 14                    30.0
# 1050357           1                 14                    30.0
# 1050357           1                 14                    30.0
#
#                                            product_name  aisle_id  \
# order_id
# 1050357                              Organic Egg Whites        86
# 1050357                       Organic Turkey Bone Broth         5
# 1050357                              Organic Quick Oats       130
# 1050357                        Organic Broccoli Florets       116
# 1050357                 Lightly Salted Brown Rice Cakes        78
# 1050357                   Organic Sunflower Seed Spread        88
# 1050357                                 Black Eyed Peas       116
# 1050357      Organic Raw Unfiltered Apple Cider Vinegar        19
# 1050357              Organic Balsamic Vinegar Of Modena        19
# 1050357   Dairy Free French Vanilla Creamer Almond Milk       100
#
#           department_id
# order_id
# 1050357              16
# 1050357              13
# 1050357              14
# 1050357               1
# 1050357              19
# 1050357              13
# 1050357               1
# 1050357              13
# 1050357              13
# 1050357              21

# %%
products[products["product_id"]==28985]
# Out:
#        product_id product_name  aisle_id  department_id
# 17793       17794      Carrots        83              4

# %%
prior[prior["user_id"]==202279]["product_id"].value_counts().head(10)
# Out:
# 17794    7
# 1003     6
# 28985    5
# 33120    5
# 40141    5
# 45918    5
# 35106    3
# 10960    3
# 30035    3
# 31275    3
# Name: product_id, dtype: int64

# %%
train[train["user_id"]==202279]["product_id"].value_counts()
# Out:
# 46064    1
# 4461     1
# 1003     1
# 45002    1
# 20168    1
# 21543    1
# 8693     1
# 20995    1
# 42824    1
# 33120    1
# Name: product_id, dtype: int64
